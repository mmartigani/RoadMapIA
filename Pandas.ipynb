# %% [markdown]
# <a href="https://colab.research.google.com/github/mmartigani/RoadMapIA/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos = {"nombre":["zero", "cool", "linux"], "edad":[23,45,67]}
datos
# Out:
# {'nombre': ['zero', 'cool', 'linux'], 'edad': [23, 45, 67]}

# %%
df = pd.DataFrame(datos)
df
# Out:
#   nombre  edad
# 0   zero    23
# 1   cool    45
# 2  linux    67

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df["nombre"]
# Out:
# 0     zero
# 1     cool
# 2    linux
# Name: nombre, dtype: object

# %%
df.nombre
# Out:
# 0     zero
# 1     cool
# 2    linux
# Name: nombre, dtype: object

# %%
df = pd.read_csv("/content/Precipitaciones.csv")
df.head(3)
# Out:
#      region  enero  febrero  marzo  abril   mayo  junio  julio  agosto  \
# 0  A CORUNA  240.5    293.4   31.0   80.6  149.5  108.9   44.6    21.8
# 1  ALBACETE   68.1     28.0   26.2   65.3   25.4   50.0    2.0    34.5
# 2  ALICANTE   49.2      3.7   63.2   85.8   57.2   20.0    9.2     5.0
#
#    septiembre  octubre  noviembre  diciembre   anual
# 0        96.5    154.5      100.8      214.8  1536.9
# 1        48.0     44.8       33.1       14.1   439.5
# 2        44.0     41.1       47.4        1.8   427.6

# %%
df.tail(2)
# Out:
#       region  enero  febrero  marzo  abril  mayo  junio  julio  agosto  \
# 50    ZAMORA   53.0    112.0    6.8   63.7  19.8   54.2    3.1     9.6
# 51  ZARAGOZA   52.0     30.0    3.6   52.7  38.3   57.5   13.5    13.2
#
#     septiembre  octubre  noviembre  diciembre  anual
# 50        78.5     55.3       29.0       50.3  535.3
# 51        61.5     27.4       76.6       23.4  449.7

# %%
df.describe()
# Out:
#             enero     febrero       marzo       abril        mayo       junio  \
# count   52.000000   52.000000   52.000000   52.000000   52.000000   52.000000
# mean    92.996154   78.632692   26.684615   64.500000   38.305769   54.182692
# std     57.127171   67.454280   31.473913   21.421942   29.079576   36.821635
# min     26.800000    2.300000    3.300000    3.500000    0.700000    1.100000
# 25%     53.825000   32.825000    9.125000   53.950000   18.875000   26.325000
# 50%     73.950000   62.600000   17.200000   62.700000   35.650000   50.400000
# 75%     97.300000  102.550000   35.425000   77.625000   48.750000   78.025000
# max    261.900000  335.700000  209.800000  128.400000  149.500000  145.000000
#
#            julio     agosto  septiembre     octubre   noviembre   diciembre  \
# count  52.000000  52.000000   52.000000   52.000000   52.000000   52.000000
# mean   11.840385  17.178846   62.246154   54.373077   82.494231   76.192308
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      52 non-null     object
#  1   enero       52 non-null     float64
#  2   febrero     52 non-null     float64
#  3   marzo       52 non-null     float64
#  4   abril       52 non-null     float64
#  5   mayo        52 non-null     float64
#  6   junio       52 non-null     float64
#  7   julio       52 non-null     float64
#  8   agosto      52 non-null     float64
#  9   septiembre  52 non-null     float64
#  10  octubre     52 non-null     float64
#  11  noviembre   52 non-null     float64
#  12  diciembre   52 non-null     float64
#  13  anual       52 non-null     float64
# dtypes: float64(13), object(1)
# memory usage: 5.8+ KB

# %%
df.shape
# Out:
# (52, 14)

# %%
df.columns
# Out:
# Index(['region', 'enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio',
#        'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre',
#        'anual'],
#       dtype='object')

# %%
serie =df["region"]
serie.head(3)
# Out:
# 0    A CORUNA
# 1    ALBACETE
# 2    ALICANTE
# Name: region, dtype: object

# %%
datos = [10,20,30,40,50]
serie2 = pd.Series(datos)
serie2
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
indices=["a","b","c","d","e"]
serie3 = pd.Series(datos, index=indices)
serie3
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
serie3["b"]
# Out:
# np.int64(20)

# %%
capitales = {"españa":"madrid", "peru":"lima","argentina":"buenos aires"}
serie4 = pd.Series(capitales)
serie4
# Out:
# españa             madrid
# peru                 lima
# argentina    buenos aires
# dtype: object

# %%
serie2 = serie2 + 10
serie2
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# 4    60
# dtype: int64

# %%
serie2 = serie2 * 3
serie2
# Out:
# 0     60
# 1     90
# 2    120
# 3    150
# 4    180
# dtype: int64

# %%
data = {"id_producto":[1001,1002,1003,1003],
        "cantidad_vendida":[30, None,25,25],
        "precio":[20.5,15.0, None,22.5]}
df = pd.DataFrame(data)
df
# Out:
#    id_producto  cantidad_vendida  precio
# 0         1001              30.0    20.5
# 1         1002               NaN    15.0
# 2         1003              25.0     NaN
# 3         1003              25.0    22.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_producto       4 non-null      int64
#  1   cantidad_vendida  3 non-null      float64
#  2   precio            3 non-null      float64
# dtypes: float64(2), int64(1)
# memory usage: 228.0 bytes

# %%
df.isnull()
# Out:
#    id_producto  cantidad_vendida  precio
# 0        False             False   False
# 1        False              True   False
# 2        False             False    True
# 3        False             False   False

# %%
df.isnull().sum()
# Out:
# id_producto         0
# cantidad_vendida    1
# precio              1
# dtype: int64

# %%
df_eliminados = df.dropna()
df_eliminados
# Out:
#    id_producto  cantidad_vendida  precio
# 0         1001              30.0    20.5
# 3         1003              25.0    22.5

# %%
valores_nuevos ={"cantidad_vendida":0,"precio":df["precio"].mean()}
df_rellenados = df.fillna(valores_nuevos)
df_rellenados
# Out:
#    id_producto  cantidad_vendida     precio
# 0         1001              30.0  20.500000
# 1         1002               0.0  15.000000
# 2         1003              25.0  19.333333
# 3         1003              25.0  22.500000

# %%
df_rellenados["cantidad_vendida"] = df_rellenados["cantidad_vendida"].astype(int)
df_rellenados
# Out:
#    id_producto  cantidad_vendida     precio
# 0         1001                30  20.500000
# 1         1002                 0  15.000000
# 2         1003                25  19.333333
# 3         1003                25  22.500000

# %%
df_rellenados["precio"] = df_rellenados["precio"].astype(int)
df_rellenados
# Out:
#    id_producto  cantidad_vendida  precio
# 0         1001                30      20
# 1         1002                 0      15
# 2         1003                25      19
# 3         1003                25      22

# %%
df_unicos = df_rellenados.drop_duplicates(subset="id_producto")
df_unicos
# Out:
#    id_producto  cantidad_vendida     precio
# 0         1001                30  20.500000
# 1         1002                 0  15.000000
# 2         1003                25  19.333333

# %%
serie5 = pd.Series([5,10,15,20,25])
serie5
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
filtro = serie5 > 15
serie_filtrada = serie5[filtro]
serie_filtrada
# Out:
# 3    20
# 4    25
# dtype: int64

# %%
filtro
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
serie6 = pd.Series(["zero", "cool","linux","docker"])
serie6
# Out:
# 0      zero
# 1      cool
# 2     linux
# 3    docker
# dtype: object

# %%
print(type(serie6))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(serie6[0]))
# Out:
# <class 'str'>

# %%
filtro2 = serie6.str.contains("z")
filtro2
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
serie6[filtro2]
# Out:
# 0    zero
# dtype: object

# %%
numeros = pd.Series([10,20,30,40,50])
numeros
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
promedio = numeros.mean()
promedio
# Out:
# np.float64(30.0)

# %%
promedio = numeros.mean()
print(f"el promedio es {promedio}")
# Out:
# el promedio es 30.0

# %%
total = numeros.sum()
total
# Out:
# np.int64(150)

# %%
maximo = numeros.max()
maximo
# Out:
# 50

# %%
minimo = numeros.min()
minimo
# Out:
# 10

# %%
ruta = pd.read_csv("/content/medallas.csv")
ruta
# Out:
#      Oro  Plata  Bronce  Total          Pais
# 0    NaN    1.0     2.0      3     Argentina
# 1    NaN    2.0     2.0      4       Armenia
# 2   17.0    7.0    22.0     46     Australia
# 3    1.0    1.0     5.0      7       Austria
# 4    NaN    3.0     4.0      7    Azerbaijan
# ..   ...    ...     ...    ...           ...
# 88   NaN    1.0     NaN      1  Turkmenistan
# 89   2.0    1.0     1.0      4        Uganda
# 90   1.0    6.0    12.0     19       Ukraine
# 91   3.0    NaN     2.0      5    Uzbekistan
# 92   1.0    3.0     NaN      4     Venezuela
#
# [93 rows x 5 columns]

# %%
ruta.shape
# Out:
# (93, 5)

# %%
ruta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Oro     65 non-null     float64
#  1   Plata   69 non-null     float64
#  2   Bronce  76 non-null     float64
#  3   Total   93 non-null     int64
#  4   Pais    93 non-null     object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 3.8+ KB

# %%
ruta.describe()
# Out:
#              Oro      Plata     Bronce       Total
# count  65.000000  69.000000  76.000000   93.000000
# mean    4.400000   4.768116   4.934211   10.548387
# std     7.633806   7.276362   6.261705   18.897617
# min     1.000000   1.000000   1.000000    1.000000
# 25%     1.000000   1.000000   1.000000    2.000000
# 50%     2.000000   2.000000   2.000000    4.000000
# 75%     3.000000   5.000000   5.250000    8.000000
# max    39.000000  41.000000  33.000000  113.000000

# %%
ruta.isnull().sum()
# Out:
# Oro       28
# Plata     24
# Bronce    17
# Total      0
# Pais       0
# dtype: int64

# %%
ruta.fillna(0, inplace=True)
ruta.head(4)
# Out:
#     Oro  Plata  Bronce  Total       Pais
# 0   0.0    1.0     2.0      3  Argentina
# 1   0.0    2.0     2.0      4    Armenia
# 2  17.0    7.0    22.0     46  Australia
# 3   1.0    1.0     5.0      7    Austria

# %%
ruta["Oro"] = ruta["Oro"].astype(int)
ruta["Plata"] = ruta["Plata"].astype(int)
ruta["Bronce"] = ruta["Bronce"].astype(int)
ruta.head(4)
# Out:
#    Oro  Plata  Bronce  Total       Pais
# 0    0      1       2      3  Argentina
# 1    0      2       2      4    Armenia
# 2   17      7      22     46  Australia
# 3    1      1       5      7    Austria

# %%
top3 = ruta.sort_values(by="Oro", ascending=False).head(3)
top3
# Out:
#     Oro  Plata  Bronce  Total                        Pais
# 25   39     41      33    113   Estados Unidos de America
# 72   38     32      18     88  Republica Popular de China
# 46   27     14      17     58                       Japon

# %%
filtrados = ruta["Total"] > 10
mas_10_medallas = ruta[filtrados]
mas_10_medallas.sort_values(by="Total", ascending=False).head(7)
# Out:
#     Oro  Plata  Bronce  Total                        Pais
# 25   39     41      33    113   Estados Unidos de America
# 72   38     32      18     88  Republica Popular de China
# 73    2     28      23     71                         ROC
# 34   22     21      22     65                Gran Bretana
# 46   27     14      17     58                       Japon
# 2    17      7      22     46                   Australia
# 32    1     11      16     37                     Germany
