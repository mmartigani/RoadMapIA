# %% [markdown]
# <a href="https://colab.research.google.com/github/mmartigani/RoadMapIA/blob/main/mysql_Command_Line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#nos conectamos al command line de mysql
\sql
\connect@rootlocalhost
show databases;
#creamos la base de datos
CREATE DATABASE tech_db;
USE tech_db;

#creacion de tablas
CREATE TABLE authors (
    author_id INT AUTO_INCREMENT PRIMARY KEY,
    name VARCHAR(100) NOT NULL,
    email VARCHAR(100) UNIQUE NOT NULL
);

CREATE TABLE categories (
    category_id INT AUTO_INCREMENT PRIMARY KEY,
    category_name VARCHAR(100) NOT NULL
);

CREATE TABLE articles (
    article_id INT AUTO_INCREMENT PRIMARY KEY,
    title VARCHAR(150) NOT NULL,
    content TEXT,
    author_id INT,
    category_id INT,
    published_date DATE,
    FOREIGN KEY (author_id) REFERENCES authors(author_id),
    FOREIGN KEY (category_id) REFERENCES categories(category_id)
);
#insertamos lo datos
INSERT INTO authors (name, email) VALUES
('Alice Johnson', 'alice@technews.com'),
('Bob Smith', 'bob@cybermail.com'),
('Carla Gómez', 'carla@futureai.org');

INSERT INTO categories (category_name) VALUES
('Inteligencia Artificial'),
('Ciberseguridad'),
('Desarrollo Web');

INSERT INTO articles (title, content, author_id, category_id, published_date) VALUES
('Machine Learning en 2025', 'El futuro del ML con nuevos modelos...', 1, 1, '2025-06-01'),
('Cómo prevenir ataques DDoS', 'Guía completa de seguridad...', 2, 2, '2025-06-10'),
('Frameworks modernos de frontend', 'Comparativa entre React, Vue y Svelte...', 3, 3, '2025-06-15');


SHOW TABLES;
DESCRIBE articles;
SELECT * FROM authors;
SELECT * FROM categories;
SELECT * FROM articles;

# %%
from PIL import Image
import matplotlib.pyplot as plt
image_path = '/content/Captura de pantalla 2025-06-22 184731.png'
try:
    img = Image.open(image_path)
    plt.imshow(img)
    plt.axis('off')
    plt.show()
except FileNotFoundError:
    print(f"Error: No se encontró el archivo en la ruta {image_path}.")

# %%
from PIL import Image
import matplotlib.pyplot as plt
image_path = '/content/Captura de pantalla 2025-06-22 184803.png'
try:
    img = Image.open(image_path)
    plt.imshow(img)
    plt.axis('off')
    plt.show()
except FileNotFoundError:
    print(f"Error: No se encontró el archivo en la ruta {image_path}.")
