# %% [markdown]
# <a href="https://colab.research.google.com/github/mmartigani/RoadMapIA/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
numeros = [4,2,7,6,3]

# %%
plt.plot(numeros)
plt.show()

# %%
plt.plot(numeros)
plt.savefig("primero.png");

# %%
plt.figure(facecolor="orange",figsize=(5,5))
plt.plot(numeros)

# %%
plt.subplots(ncols=2,nrows=2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
fig, axs =plt.subplots(ncols=2,nrows=2)

# %%
fig = plt.figure()
ax = plt.axes()

# %%
plt.grid()

# %%
x = [1, 2, 3, 5, 5, 6, 7]
y = [1, 6, 3, 4, 5, 6, 7]
plt.plot(x, y);

# %%
plt.plot(x, y)
plt.grid();

# %%
plt.plot(x, y, "ro-")
plt.grid();

# %%
plt.plot(x, y, "b*:")
plt.grid();

# %%
plt.plot(x, y, "b*:")
plt.axis([0, 8, 0, 8])
plt.grid();

# %%
ruta = "/content/Lluvias_region_A.csv"
df = pd.read_csv(ruta)
df
# Out:
#      region  enero  febrero  marzo  abril   mayo  junio  julio  agosto  \
# 0  A CORUNA  240.5    293.4   31.0   80.6  149.5  108.9   44.6    21.8
# 1  ALBACETE   68.1     28.0   26.2   65.3   25.4   50.0    2.0    34.5
# 2  ALICANTE   49.2      3.7   63.2   85.8   57.2   20.0    9.2     5.0
# 3   ALMERIA   56.3      5.2   35.8   43.1   38.8   16.9   10.2     1.9
# 4     ARABA   96.8     79.9   38.0   52.0   37.7  107.8    8.5    17.7
# 5  ASTURIAS  196.9    138.4   34.4   73.1   67.4  131.2   22.5    19.2
# 6     AVILA   67.6    104.5    5.6   83.4   25.7   44.4    5.5    14.2
#
#    septiembre  octubre  noviembre  diciembre   anual
# 0        96.5    154.5      100.8      214.8  1536.9
# 1        48.0     44.8       33.1       14.1   439.5
# 2        44.0     41.1       47.4        1.8   427.6
# 3        17.4     27.3       32.6        3.2   288.7
# 4        63.3     38.5      212.2      197.3   949.7
# 5        90.3     74.2      309.8      205.3  1362.7
# 6        97.9     91.7       33.9       47.5   621.9

# %%
plt.plot(df['region'],df['enero']);

# %%
plt.plot(df['region'],df['enero'])
plt.xticks(rotation=45);

# %%
df = pd.read_csv("/content/Ventas.csv")
df.head(5)
# Out:
#        Fecha    Producto  Cantidad  Precio Unitario  Total Venta
# 0  1/17/2023  Electrónic         7              200         1400
# 1   9/1/2023  Electrónic         8              200         1600
# 2  7/29/2023    Juguetes         3               30           90
# 3  10/4/2023   Alimentos         4               10           40
# 4  2/28/2023  Electrónic         6              200         1200

# %%
plt.hist(df['Producto']);

# %%
numeros = np.random.randn(1000)
numeros
# Out:
# array([ 0.88393891,  1.87994728, -1.67261394,  0.3317287 ,  0.60184947,
#        -0.26357705,  0.52619666, -0.9697145 , -0.5687838 ,  0.63990029,
#        -1.94522349, -0.06649501,  0.77064355, -1.34269464,  1.50713273,
#        -0.86157542, -0.0526202 ,  0.63251032,  0.14580236,  0.10112723,
#        -0.26519054, -0.20425859,  1.10546692, -1.3955004 , -2.00606036,
#         2.64282405,  1.82202137, -1.37829327, -0.4735533 ,  0.09849454,
#        -0.56528707, -0.61536331, -1.1795053 ,  0.73834286, -1.14533371,
#         0.76033717, -1.65902314, -0.08260722, -0.21030418,  1.56614456,
#        -0.19087598, -0.52310712,  0.40403449,  1.09164872, -0.12084114,
#        -0.38445858,  1.50444454,  0.60702081,  1.38073346, -1.00250316,
#        -0.85899153, -0.68362436,  0.32021318, -0.12797184,  1.30180104,
#        -0.61045172,  2.32728857,  0.65121074, -0.33950507, -0.74676195,
#        -0.79753498,  0.24426434,  0.53137617, -1.38118093, -0.48027065,
#        -0.31884019, -0.32879135, -1.17847874,  0.82448511,  0.25437492,
#        -1.51055789, -0.85519656, -0.31913739,  1.50133513, -0.6667339 ,
#         0.79882686,  1.39616294,  0.291003  , -1.20917594,  0.85642899,
#         2.09197742,  1.06615279,  0.03402277,  1.78088845, -0.64729906,
#        -1.18510575, -0.25708133,  0.23421989,  1.51270855, -0.05517819,
#         0.40016031,  0.22009951, -0.6678756 ,  0.63137396, -0.24175518,
#         0.17006248,  0.33579391, -0.51645051, -1.12284336,  0.09816418,
#        -2.06274643,  0.70649016,  1.80871829, -0.83010145,  0.13178918,
#         0.95645431, -1.24603564, -0.25186993,  0.40784187, -1.3963034 ,
#        -1.29252178,  0.39778651, -0.55834487, -0.97242956,  0.53604233,
#        -0.02413803,  1.74048252, -0.21654993,  0.4981117 ,  0.88565079,
#         0.4944434 , -0.95829579, -2.83609404, -1.12372916, -0.28069944,
#         1.13710922, -0.1858448 , -0.83078213,  0.17473989, -0.83447164,
#         0.49438733,  0.15999372, -2.19944365,  0.19686262,  1.4369666 ,
#         0.21391653,  0.14858169, -1.34152154, -0.21957394,  0.47066771,
#        -0.63882026, -0.17902614,  0.69012162, -0.3310381 ,  0.34458137,
#         1.44187186, -0.78330863, -0.60462869, -1.15255178,  0.41794203,
#         0.19493658, -0.08522846,  0.18339827, -1.06075311,  0.41507755])

# %%
plt.hist(numeros);

# %%
plt.hist(numeros, bins=40);

# %%
plt.hist(numeros, bins=40, alpha=0.5);

# %%
plt.hist(numeros, bins=40, alpha=0.5, color='red');

# %%
plt.hist(numeros, bins=40, alpha=0.5, color='red', edgecolor='green');

# %%
plt.hist(numeros, bins=40, alpha=0.5, color='red', edgecolor='green', histtype='step');

# %%
x1 = np.random.randn(1000)
x2 = np.random.randn(500)
x3 = np.random.randn(100)

plt.hist(x1, histtype='stepfilled', alpha=0.3, bins=40)
plt.hist(x2, histtype='stepfilled', alpha=0.3, bins=40)
plt.hist(x3, histtype='stepfilled', alpha=0.3, bins=40);

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

# %%
plt.plot(x, y);

# %%
plt.plot(x, y, 'o');

# %%
aleatorio = np.random.RandomState(0)
marcadores = ['o', 'x', '+', 'v', 's', 'd']
for marcador in marcadores:
    plt.plot(aleatorio.rand(5), aleatorio.rand(5), marcador)

# %%
plt.plot(x, y, ':ob');

# %%
plt.plot(x, y, '-p');

# %%
plt.plot(x, y, '-p', color='red');

# %%
plt.plot(x, y, '-p', color='red', markersize=15);

# %%
plt.plot(x, y, '-p', color='red', markersize=15, linewidth=4);

# %%
plt.plot(x, y, '-p', color='red', markersize=15, linewidth=4, markerfacecolor='white');

# %%
plt.scatter(x, y);

# %%
aleatorio = np.random.RandomState(0)
plt.scatter(aleatorio.randn(100),
           aleatorio.randn(100),
           c=aleatorio.randn(100),
           s=aleatorio.randn(100) * 1000,
           alpha=0.3,
           cmap='viridis')
plt.colorbar();
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df = pd.DataFrame({
    "etiquetas":['Manzanas', 'Bananas', 'Naranjas', 'Uvas'],
    "cantidad":[30, 60, 80, 20]
})
df
# Out:
#   etiquetas  cantidad
# 0  Manzanas        30
# 1   Bananas        60
# 2  Naranjas        80
# 3      Uvas        20

# %%
plt.pie(df['cantidad']);

# %%
plt.pie(df['cantidad'],
       labels=df['etiquetas']);

# %%
plt.pie(df['cantidad'],
       labels=df['etiquetas'],
       autopct='%1.1f%%');

# %%
plt.pie(df['cantidad'],
       labels=df['etiquetas'],
       autopct='%1.1f%%',
       colors=['#87CEEB', '#6495ED', '#000080', '#40E0D0']);

# %%
plt.pie(df['cantidad'],
       labels=df['etiquetas'],
       autopct='%1.1f%%',
       colors=['#87CEEB', '#6495ED', '#000080', '#40E0D0'],
       shadow=True);

# %%
plt.pie(df['cantidad'],
       labels=df['etiquetas'],
       autopct='%1.1f%%',
       colors=['#87CEEB', '#6495ED', '#000080', '#40E0D0'],
       shadow=True,
       explode=(0, 0, 0, 0.5));

# %%
plt.pie(df['cantidad'],
       labels=df['etiquetas'],
       autopct='%1.1f%%',
       colors=['#87CEEB', '#6495ED', '#000080', '#40E0D0'],
       shadow=True,
       explode=(0, 0, 0, 0.5))
plt.title("Mis frutas");

# %%
fig, axs = plt.subplots(ncols=2, nrows=2);

# %%
fig, axs = plt.subplots(ncols=2, nrows=1);

# %%
fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1];

# %%
fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot([1, 2, 3, 4], [1, 4, 9, 16])
ax2.scatter([1, 2, 3, 4], [1, 4, 9, 16]);

# %%
fig, axs = plt.subplots(ncols=2, nrows=1)

ax1 = axs[0]
ax2 = axs[1]
ax1.plot([1, 2, 3, 4], [1, 4, 9, 16])
ax2.scatter([1, 2, 3, 4], [1, 4, 9, 16])
ax1.set_title("Gráfico de Línea")
ax2.set_title("Gráfico Scatter");

# %%
df = pd.DataFrame({
    "etiquetas":['Manzanas', 'Bananas', 'Naranjas', 'Uvas'],
    "cantidad":[30, 35, 26, 33]
    })
df
# Out:
#   etiquetas  cantidad
# 0  Manzanas        30
# 1   Bananas        35
# 2  Naranjas        26
# 3      Uvas        33

# %%
fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot(df['etiquetas'], df['cantidad'])
ax2.pie(df['cantidad']);

# %%
plt.style.use('ggplot')

fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot(df['etiquetas'], df['cantidad'])
ax2.pie(df['cantidad']);

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-pastel')

fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot(df['etiquetas'], df['cantidad'])
ax2.pie(df['cantidad']);

# %%
plt.style.use('fivethirtyeight')

fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot(df['etiquetas'], df['cantidad'])
ax2.pie(df['cantidad']);

# %%
plt.style.use('dark_background')

fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot(df['etiquetas'], df['cantidad'])
ax2.pie(df['cantidad']);

# %%
df = pd.read_csv("/content/Iluminacion.csv")
df
# Out:
#        Latitud  Longitud  Luminosidad
# 0     1.764052 -0.202117    49.929240
# 1     0.400157 -0.833231    98.656690
# 2     0.978738  1.733600    68.735218
# 3     2.240893  0.190649    85.794230
# 4     1.867558 -0.177810    50.499409
# ...        ...       ...          ...
# 9995 -1.809282  0.271662    65.661394
# 9996  0.042359 -0.108997    42.123643
# 9997  0.516872 -0.057259    18.950191
# 9998 -0.032921 -1.058931     8.672976
# 9999  1.298111 -0.326528    14.826581
#
# [10000 rows x 3 columns]

# %%
fig, ax = plt.subplots()
ax.hexbin(df['Latitud'], df['Longitud'], gridsize=20);

# %%
fig, ax = plt.subplots()
ax.hexbin(df['Latitud'], df['Longitud'], C=df['Luminosidad'], gridsize=20);

# %%
fig, ax = plt.subplots()
ax.hexbin(df['Latitud'], df['Longitud'], C=df['Luminosidad'], gridsize=50);

# %%
fig, ax = plt.subplots()
ax.hexbin(df['Latitud'], df['Longitud'], C=df['Luminosidad'], gridsize=50, cmap='Greens');

# %%
fig, ax = plt.subplots()
ax.hexbin(df['Latitud'], df['Longitud'], C=df['Luminosidad'], gridsize=50, cmap='Greens')
ax.set_facecolor('#000000');

# %%
fig, ax = plt.subplots()
hb = ax.hexbin(df['Latitud'], df['Longitud'], C=df['Luminosidad'], gridsize=50, cmap='Greens')
ax.set_facecolor('#000000')
plt.colorbar(hb, label="nivel de sombras");

# %%
fig, ax = plt.subplots()
hb = ax.hexbin(df['Latitud'], df['Longitud'], C=df['Luminosidad'], gridsize=50, cmap='Greens')
ax.set_facecolor('#000000')
plt.colorbar(hb, label="nivel de sombras")
plt.xlabel("Latitud")
plt.ylabel("Longitud");

# %%
fig, ax = plt.subplots()
hb = ax.hexbin(df['Latitud'], df['Longitud'], C=df['Luminosidad'], gridsize=50, cmap='Greens')
ax.set_facecolor('#000000')
plt.colorbar(hb, label="nivel de sombras")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.title("Luminosidad en Villa Luz");

# %%
ruta = "/content/Datos+Meteorológicos_Arg_2023.csv"
df = pd.read_csv(ruta)
df.head()
# Out:
#       Fecha        Ciudad  Temperatura Maxima  Temperatura Minima  \
# 0  1/1/2023  Buenos Aires                  27                  18
# 1  1/1/2023       Cordoba                  35                  18
# 2  1/1/2023       Rosario                  23                  21
# 3  1/1/2023       Mendoza                  35                  21
# 4  1/1/2023       Tucuman                  36                  18
#
#    Precipitacion  Velocidad del Viento  Humedad Relativa
# 0            0.0                  22.7              68.8
# 1            0.0                  33.8              61.7
# 2            0.0                  10.6              80.0
# 3            0.0                  23.8              76.8
# 4           17.2                  25.7              54.9

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'], format='%d/%m/%Y')
df.head()
# Out:
#        Fecha        Ciudad  Temperatura Maxima  Temperatura Minima  \
# 0 2023-01-01  Buenos Aires                  27                  18
# 1 2023-01-01       Cordoba                  35                  18
# 2 2023-01-01       Rosario                  23                  21
# 3 2023-01-01       Mendoza                  35                  21
# 4 2023-01-01       Tucuman                  36                  18
#
#    Precipitacion  Velocidad del Viento  Humedad Relativa
# 0            0.0                  22.7              68.8
# 1            0.0                  33.8              61.7
# 2            0.0                  10.6              80.0
# 3            0.0                  23.8              76.8
# 4           17.2                  25.7              54.9

# %%
lista_ciudades = []

for c in df['Ciudad']:
    if c not in lista_ciudades:
        lista_ciudades.append(c)

lista_ciudades
# Out:
# ['Buenos Aires', 'Cordoba', 'Rosario', 'Mendoza', 'Tucuman']

# %%
dict_meses = {1: 'Enero',
             2: 'Febrero',
             3: 'Marzo',
             4: 'Abril',
             5: 'Mayo',
             6: 'Junio',
             7: 'Julio',
             8: 'Agosto',
             9: 'Septiembre',
             10: 'Octubre',
             11: 'Noviembre',
             12: 'Diciembre'}

# %%
def consultar_temperaturas():
    while True:
        # solicitar la ciudad
        print("\nCiudades disponibles: ", lista_ciudades)
        ciudad_elegida = input("Elija la ciudad de la lista: ").title()

        # Solicitar el mes
        mes_elegido = int(input("Elija un número de mes (por ej. Enero = 1): "))

        # validar los inputs
        if ciudad_elegida not in lista_ciudades or mes_elegido not in range(1, 13):
            print("Ciudad o mes no válidos. Inténtale nuevamente.")
            continue

        # Crear el datafreme filtrado
        datos_ciudad_mes = df[(df['Ciudad'] == ciudad_elegida) & (df['Fecha'].dt.month == mes_elegido)]

        # Graficamos las temperaturas del dataframe
        plt.figure(figsize=(10, 6))
        plt.plot(datos_ciudad_mes['Fecha'], datos_ciudad_mes['Temperatura Maxima'], label="Maxima", color="red")
        plt.plot(datos_ciudad_mes['Fecha'], datos_ciudad_mes['Temperatura Minima'], label="Minima", color="blue")
        plt.title(f"Temperaturas en {ciudad_elegida} durante el mes de {dict_meses[mes_elegido]}")
        plt.xlabel("Fecha")
        plt.ylabel("Temperaturas")
        plt.legend()
        plt.xticks(rotation=45)
        plt.show()

        # Preguntar al usuario si quiere continuar
        otra_consulta = input("¿Deseas continuar consultando? (s/n): ")
        if otra_consulta.lower() != 's':
            break

# %%
consultar_temperaturas()
# Out:
# Ciudades disponibles:  ['Buenos Aires', 'Cordoba', 'Rosario', 'Mendoza', 'Tucuman']
# Elija la ciudad de la lista: Cordoba
# Elija un número de mes (por ej. Enero = 1): 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-96-277866501.py in <cell line: 0>()
# ----> 1 consultar_temperaturas()
#
# /tmp/ipython-input-95-2354690337.py in consultar_temperaturas()
#      28
#      29         # Preguntar al usuario si quiere continuar
# ---> 30         otra_consulta = input("¿Deseas continuar consultando? (s/n): ")
#      31         if otra_consulta.lower() != 's':
#      32             break
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
