# %% [markdown]
# <a href="https://colab.research.google.com/github/mmartigani/RoadMapIA/blob/main/Docker_Kali_Linux2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sudo apt update
sudo apt install -y docker.io
wget https://http.kali.org/kali/pool/main/k/kali-archive-keyring/kali-archive-keyring_2025.1_all.deb
sudo dpkg -i kali-archive-keyring_2025.1_all.deb
rm kali-archive-keyring_2025.1_all.deb
sudo apt-get update -y
sudo apt install -y docker.io
sudo systemctl enable docker --now
echo "deb [arch=amd64 signed-by=/etc/apt/keyrings/docker.gpg] https://download.docker.com/linux/debian bookworm stable" | \
  sudo tee /etc/apt/sources.list.d/docker.list
curl -fsSL https://download.docker.com/linux/debian/gpg |
  sudo gpg --dearmor -o /etc/apt/keyrings/docker.gpg
sudo apt update
sudo apt install -y docker-ce docker-ce-cli containerd.io
sudo systemctl enable docker --now
sudo docker run hello-world
sudo docker -v
sudo docker compose version
sudo groupadd docker
sudo usermod -aG docker $USER
sudo nano /etc/docker/daemon.json
{
  "log-driver":"json-file",
  "log-opts": {
    "max-size":"10m",
    "max-file":"3"
  }
}
sudo apt install net-tools
sudo apt install telnet
docker ps -a
docker run -d -p 80:80 docker/getting-started
sudo lsof -i -P -n | grep 80
docker image ls
docker ps -a
docker ps
docker run -p 8080:80 -p 7080:7080 --name conBilling sotobotero/billingapp
en otra terminal
docker image ls
docker ps
abro un navegador para ver la app : localhost:8080
telnet localhost 8080
para detener el contenedor y eliminarlo
control c
docker ps -a
elimanos las imagenes todas
docker system prune --all
docker ps -a
docker image ls
vuelvo a recrear la app/imagen
docker run -p 8080:80 -p 7080:7080 --name conBilling sotobotero/billingapp
buscamos una imagen en dockerhub : https://hub.docker.com/
docker run -p 8080:80 -p 7080:7080 --name conBilling sotobotero/billingapp
si detenemos un contenedor para volver a reiniciarlo
docker start conBilling
https://hub.docker.com/_/postgres/tags?name=13
docker pull postgres:13.12
docker images ls
docker run --ulimit memlock=-1:-1 -d --name postgres -e POSTGRES_USER=sa -e POSTGRES_PASSWORD=admin -e POSTGRES_DB=product_db -p 5432:5432 postgres 13.12
docker logs conBilling
docker stop conBilling
docker start conBilling
docker stop $(docker ps -q)
docker system prune --all
docker image ls
ärchivo Dockerfile en nano
FROM nginx:stable-alpine

VOLUME  /tmp

RUN rm -rf /usr/share/nginx/html/*

COPY nginx.conf /etc/nginx/nginx.conf
COPY dist/billingApp /usr/share/nginx/html
COPY mime.types /etc/nginx/mine.types

RUN apk --no-cache add openjdk17-jre

ENV JAVA_HOME /usr/lib/jvm/java-17-openjdk
ENV PATH $JAVA_HOME/bin:$PATH

RUN java -version

ENV JAVA_OPIS=""
ARG JAR_FILE
ADD ${JAR_FILE} app.jar


COPY appshell.sh appshell.sh
EXPOSE 80 7080
---
sudo docker build -t billingapp --no-cache --build-arg JAR_FILE=target/*.jar .
sudo docker run -d  -p 80:80 -p 7080:7080 --name localbillingApp billingapp

crear una cuenta en dockerhub para que nos deje crear y publicar un repositorio de imagen
repositorio / crear repositorio / colocar nombre y descripcion / crear
nos devuelve el comando de nuestra imagen
docker push zero171717/zerocool:tagname
sudo docker tag billingapp zero171717/zerocool
sudo docker image ls
sudo docker tag billingapp zero171717/zerocool:v1
docker login
sudo docker push zero171717/zerocool
sudo docker pull zero171717/zerocool:latest

# %%
from PIL import Image
import matplotlib.pyplot as plt
image_path = '/content/Captura de pantalla 2025-06-30 003242.png'
try:
    img = Image.open(image_path)
    plt.imshow(img)
    plt.axis('off')
    plt.show()
except FileNotFoundError:
    print(f"Error: No se encontró el archivo en la ruta {image_path}.")
