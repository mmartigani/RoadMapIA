# %% [markdown]
# <a href="https://colab.research.google.com/github/mmartigani/RoadMapIA/blob/main/Linux.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Linux commands
#pwd
#ls
#ls -l
#ls -a
#ls -ls
#ls -lt
#ls -ld
#ls -lS
#ls -lh
#ls -lShr
#cd /home
#cd /home/ cd zero
#cd /home/zero $ cd ..
#cd /home/zero $ cd .. /..
#cd -
#cd /
#echo “hola linux”
#echo -e “ hola \n linux”
#echo -e “hola \t linux”
#echo $USER
#echo $PATH
#type cd
#type find
#type ls
#which ls
#apt-cache search manpages-es
#uname -a
#cat etc/issue
#cat etc/os-release
#set -o
#set -o history
#set +o history
#env
#export myname=zero
#evn
#echo $myname
#nset $myname
#env
#man -f ls
#man -k cp
#locate apache
#locate apache2
#locate passwd
#find / -iname “apache2.conf”
#mkdir directorio
#mkdir directorio1 directorio2
#mkdir -p musica/pop
#touch archivo.txt
#touch archivo.txt archivo.pdf
#> archivo.docs
#rm -r directorio 1
#rm archivo.txt
#mv archivo.txt mi_archivo
#mv mi_archivo directorio2/
#mv archivo.docx directorio2/archivo2.docx
#apt install tree
#tree etc
#tree dev
#tree tux
#control d = limpia pantalla
#control c = termina proceso
#control a =inicio
#control e =fin
#cp img.png /tux/
#cp img.gif /tux/img2.gif
#cp -r directorio2/ tux
#touch a.gif b.gif c.gif
#rm *.gif
#mkdir tux / cd tux / touch a.txt b.pdf c.docx d.png
#rm *
#touch archivo1 archivo2 archivo3
#cp archivo1 archivo2 archivo3 tux
#cd tux ls
#touch archivo-2022 archivo-2023 archivo-2024
#ls archivo-20??
#mkdir tux tux2 tux3
#tar -cf copia.tar tux/ tux2/ tux3/
#ls -lh copia.tar
#tar -czf copia.tar.gz tux/ tux2/ tux3/
#ls -lh copia.tar*
#du -sh tux/ tux2/ tux3/
#tar -cf log.tar /var/log/
#tar -czf log.tar.gz /var/log/
#ls -lh log.tar*
#mkdir copias
#mv *tar* copias
#cd copias/ gzip copia.tar/ ls -l copia-*
#cd copias / gunzip copia.tar.gz / ls
#cd copias / touch uno.gif dos.gif/ xz *.gif
#cd copias / unxz *.xz
#head /etc/passwd
#head -n1 /etc/passwd
#tail /etc/passwd
#tail -n1 /etc/passwd
#wc /etc/passwd
#wc -l /etc/passwd
#wc -w /etc/passwd
#wc -m /etc/passwd
#cut -c1 /etc/passwd
#cut -c1-7 /etc/passwd
#cut -c8,15 /etc/passwd
#cut -c1-7,10-15,25 etc/passwd
#cut -d”:” -f1-5 /etc/passwd
#echo “hello linux”
#echo “hello linux” > greetings.txt
#echo “ hello again” >> greetings.txt
#cat /etc/s* 2> error
#ls / cat error
#cat /etc/s* &> everything
#ls / cat todo
#echo “ hello world” | wc
#cat /etc/passwd | wc
#grep ^a /etc/passwd | cut -d1”:” -f1 | wc -l
#grep ^a /etc/passwd | cut -d1”:” -f1
#du -sh /* 2>/dev/null | sort -h | tail -n1
#grep root /etc/passwd
#grep al /etc/passwd
#grep -v al /etc/passwd
#grep root -l /var/log/*.log
#grep 100 /etc/passwd
#grep -w 100 /etc/passwd
#grep -n root /etc/passwd
#grep A /etc/passwd
#grep -i A /etc/passwd
#grep -ic A /etc/passwd
#regular expressions
#^a = it’s has to start with that letter
#$a = has to end with that letter
#.= any character
#[ ]=the ones inside are valid
#{ }=between
#[ ^ ]= excludes those inside
#sort /etc/passwd
#sort -r /etc/passwd
#sort -n /etc/passwd
#uniq -i nombres.txt
#uniq -id nombres.txt
#uniq -ic nombres.txt
#nano commands
#control x = close the file
#control o = save the file
#control w = look for a word
#control k = copi a word
#control u = paste a word
#executable file /#!/bin/bash/echo “hola mundo” / chmod +x hola.sh / ./hola.sh
#/ = root
#/bin/ binary applications
#/boot/ boot loader files
#/dev/ hardware files
#/etc/ system configuration
#/home/ users working directories
#/lib/ libraries
#/media/ removable media mount point
#/mnt/ temporarily mounted files
#/opt/ applications program packages
#/proc/ virtual files that document the nucleus
#/sbin/ binary system
#/srv/ location of data served by the system
#/sys/ documents the kernel in a hierarchical manner
#/tmp/ temporarily files
#/usr/ secondary hierarchy of user data
#/var/ variable files
#cat /proc/dma
#cat /proc/ioports
#cat /proc/interrupts
#cd /sys ls / cd class ls / cd net ls / cd enps03 ls /cat address
#cd /sys/devices/ ls
#cd /dev/cd disk/cd by-uuid / ls
#cd /etc ls
"""etc/ cat /etc/passwd
etc/ cat /etc/shadow
etc/ cat /etc/hostname
etc/ cat /etc/hosts
etc/ cat /etc/group
etc/ id user
cd boot/ ls cd grub/ ls
cd proc/ ls / cat cpuinfo
ps
ps -e
ps -f
ps -l
ps aux
pstree
top
top -n 1
htop
free
uptime
date
dmesg -H
dmesg -lerr
dmesg -lwarn
grep initr /boot/grub/grub.cfg
journalctl -S 2025-01-01 -U 2025-05-30
journalctl -S 6h30min
journalctl -p err
journalctl -p warning
journalctl _COMM=anacron
journalctl -p _PID=234
ip -c a
ifconfig | grep ‘inet’
ifconfig enp0s3
netstat -t
netstat -u
netstat -tl
netstat -tl4
nano /etc/resolv.conf = nameserver 8.8.8.8 etc
cat /etc/resolv.conf
traceroute google.com
tracepath google.com
ip link set enp0s3 down
ip  address show
ip link set enp0s3 up
ss -t
ss -t state established
ss -u
ss -tl
ss -tl4
nano /etc/hostname
nano /etc/hosts
nano /etc/network/interfaces*
ip -c a show dev enp0s3
apt install dnsutils / dig google.com
cd zero$ >cartas /chown zero:zero cartas / ls -ld cartas
chown root cartas / ls -ld cartas
chgrp zero cartas / ls -ld cartas
chmod +x file / chmod -x file
chmod u-r file / chmod o+x file
chmod u=,g=,o= file /chmod u=rwx,g=rwx,o=rwx file /
chmod 164 file / chmod 777 file / chmod 744 file / chmod 001 file  / chmod 000 file
w
who
last
useradd -d /home/cool -m -g zero -s /bin/bash cyber
ls -ld /home/cool/
id cool
useradd -m -g user1 -s /bin/bash -G zero,group1 coffee
ls -ld /home/user1
id coffee
passwd cyber
passwd -l cyber
passwd -u cyber
groupadd ia / group add ia2 / groupadd ia3
useradd -m -s /bin/bash -g ia first
useradd -m -s /bin/bash -g ia -G ia2 second
useradd -m -s /bin/bash -g ia -G ia2, ia3 third
usermod -G ia2 first
usermod -aG ia3 first
userdel -r first
groupdel ia
lspci
lspci -v
lspci -v -s 00:02
lspci | grep USB
lsusb
lsusb -t
parted -l
fdisk -l
lsmod
cd /lib/modules/ls cd amd64 etc/ ls
cd /etc/ ls -ld tc*
etc$ ls rc0.d/ -l
etc$ cd init.d/ ls
cd/lib/systemd/system/ ls
cd/lib/systemd/system/ ls default.target -l
cd/lib/systemd/system/$ cat graphical.target
cd/lib/systemd/system/$ ls *service
cd /etc/systemd/system / ls
apt install apache2
systemctl get-default
systemctl restart cron /systemctl start cron
systemctl list-dependencies
systemctl list-unit-files
systemctl cat cron.service
shutdown / apagar de forma planificada
shutdown -c / se cancela
wall / envia mensajes a todas las terminales
reboot / reiniciar
halt /apaga sin enviar señal
poweroff /apaga con envío de señal
nano /etc/default/grub
cd lib$ ldd /usr/lib/firefox-esr/
dpkg -s htop
nano /etc/apt/sources.list
echo file file2 file4 | xargs touch
kill 9 /dead the process
15 term / 19 y 20 (stop) 18(cont)
ping google.com / pgrep -l ping / pid 233
kill -20 233
kill -9 233
kill -15 233
killall ping
yes > /dev/null &  / jobs   / kill -9 %1  / jobs
ping google.com / ping facebook.com/ jobs /
fg / control z / stop
ps -T / jobs / bg / jobs
apt-get install tmux
tmux
control b c / create a new window
control “ list all window
control b  +nro = switch of the numbered  the window
control b “ = split the section horizontally
control b % = split the section vertically
control tab = switch between regions
control b n = switch between windows
control b p = see the previous window
control b espacio = predefined windows
control x = close the current region
control b $ = rename the section
tmux ls
tmux a = recover the last section
tmux a id  = select the one i want """
"""/etc/passwd $ see the users
useradd -d =home directory
useradd -m = create a home directory
useradd -g = principal group
useradd -G = secondary group
useradd -s = command interpreter
/etc/shadow$ see the password
passwd users = enter the password
passwd -l users = disable the password
passwd -u users = enable the password
chage -l = account information
chage -m = minimum number of days before changing the password
chage -d = last password change
chage -E = set expiration date
chage -I = disable the account for expiration
chage -W = days of expiration notice
chage -l alex
chage -m 1 alex
chage -m 0 alex
chage -M 1 alex
chage -d ‘2025-01-19’ alex
chage -M 30 alex
chage -l alex
/etc/skel/$ copies users directories
getent $get information
getent passwd zero
getent group zero
groupdel = delta a group
groupmod = modify a user
usermod =modidy a user
userdel = delete a user
userdel -r = delete directories home and email
crontab
m = minutes
h = hour
dom = day of the month
mon = month of year
dow = days of  the week (since zero to seven)
*= includes all possible values
cd /etc/ ls -ld cron *
/etc/ cd cron.daily/ less logrotate
etc$less contrab
etc$ crontab -e
etc$ nano /etc/ cron.deny
etc$ nano /etc/cron.allow
at now +1 minutes
at touch /root/archivo
at control c
date
atq
ls -l archivo
at 21:00
at touch /root/at2
at echo #hello” >> /root/at2
atq
at 21:00 tomorrow
at echo hello / control c
atq
cd /etc/$ ls .l at*
ls -l  /etc/ localtime
cat /etc/timezone
date
cd /etc/ $ rm timezone
etc$ ln -s /usr/share/zoneinfo/
etc$ ln -s /usr/share/zoneinfo/America/Mexixo_city localtime
ls -l localtime
date
date +%F
touch $(date +%F)_fichero_copias
ls -l 20*
echo hoy es $(date +%d)
date -s ‘2025-06-03 13:00:12’
hwclock
apt install ntpd
apt install ntp
ntpd
ntp
apt install ntpdate
date -s “2025-06-03 00:00:00”
date
ntpdate 0.spool.ntp.org
systemctl status ntpd
systemctl stop ntpd
ntpdate 0.spool.ntp.org
date
ntpd -q
atp install chrony
nano /etc/chrony/chrony.conf
systemctl status chrony
chrony
chronyc tracking
chronyc sources
timedatectl
timedatectl status
timedatectl set-time “2025-06-03 02:02:02”
timedatectl status
systemctl status rsyslog
etc$ less rsyslog.conf
etc$ cd /var/log/  ls   tail syslog  wc -l syslog
logger “hello linux”
tail /var/log/syslog
logger -p user.warning -t message  “hello linux”
tail /var/log/syslog
logger -p user.warning -t scrip “hello linux”
grep script /var/log/syslog
ect$ nano logrotate.conf
etc$ cd logrotate.d/ ls -l   less rsyslog
cd /etc/systemd/ $echo “aviso” | systemd-cat -t user -p warning
journalctl -f
journalctl - -vacuum-time=10d
journalctl - -vacuum-size=1M
etc/systemd/ $ cat /etc/machine-id
nano /etc/network/interfaces $iface enp0s3 inet dhcp
systemctl restart networking
nano /etc/network/interface $
iface enp0s3 inet static
address 192.168.18.25
netmak 255.255.255.0
gateway 192.168.18.1
systemctl  restart networking
ip -c a show dev enps03
nmcli dev status = check de wifi
nmcli dev wifi list
nmcli dev wifi connect cafe_wifi password 1234
nmcli dev status
nmcli dev show wlpls0
apt install net-tools = for the use the ipconfig
ip -r
ip route show
open two terminal
root$nc -l -p 999 enter
prueba enter
user$nc  localhost 999 enter
prueba enter control c
root$ nc -l -p 999 >fichero.llegada enter
root $ ls -lh fichero.llegada
nc -lv -p 999 > fichero.llegada enter
host google.com
dig +short google.com
apt show dnsutils
apt install dnsutils
dig google.com
dig @ 1.1.1.1 google.com
dig @ 8.8.4.4 google.com | grep time
for ZZ in “8.8.8.8” “1.1.1.1” “8.8.4.4”; do dig @$ZZ google.com | grep time ; done
apt show resolvconf
apt install resolvconf
find . -perm -002
find . -perm -002 - type d
find . -perm -002 - type d -ls
find . -perm /6000 -ls
cd /var/log/ ls  lsof syslog   pidof rsyslogd
lsof -p 112
lsof -c rsyslogd
fuser .
fuser . -v
var$ fuser log/syslog
var$ fuser log/syslog -v
apt update
apt install sudo
visudo
# %sudo ALL=(ALL:ALL)ALL
user ALL=(ALL:ALL)ALL
nano /etc/security/limits.conf
ulimit -a
nmap localhost
nmap 192.168.18.2
namp -sP 192.168.18.0/24
nampo -p 100-500 192.168.18.1-5
dpkg -l ssh
aptitude search ssh
apt show ssh
ssh 192.168.18.100
ssh alumno@192.168.18.100
cat .ssh/know_hosts
ssh-keygen / copy is key
cat .ssh/id_rsa
cat .ssh/id_rsa.pub
scp -ssh/id_rsa.pub 192.168.18.100:/root/client_key
ls (client_key)
cat -client_key >> .ssh/authorized_keys
rm  client_key
ssh 192.168.18.100
eval   `ssh-agent`
ssh-add
ssh 192.168.18.100
ssh -N f -L 8080:192.168-18.100:80 root@192.158.18.200
enter 192.168.18.100 in the browser
killall ssh """
"""lsblk
fdisk /dev/sdb
iptables -L
iptables -t filter -A INPUT -p icmp -j DROP
iptables -t filter -A INPUT -p tcp  -j DROP
iptables -t filter -P INPUT ACCEPT
iptables -t filter -P OUTPUT DROP
iptables -t filter -P FORWARD DROP
iptables -L
iptables -L -v
iptables -L -v –line-numbers
echo 1 > /proc/sys/net/ipv4/ip_forward
iptables -L
iptables -t nat -L
iptables -t nat -A POSTROUNTING -j MASQUERADE
iptables -t nat -L
iptables -P FORWARD DROP
iptables -P FORWARD ACCEPT
iptables -A FORWARD -p tcp - -dport 80 -j DROP
iptables -A FORWARD -p tcp - -dport 443 -j DROP
iptables -A FORWARD -j LOG
tail /var/log/kern.log
iptables -D FORWARD 1
iptables -A FORWARD -j LOG - - log-prefix “SNAT >>”
tail /var/log/kern.log
grep SNAT /var/log/kern.log
apt install conntrack
conntrack -L -n
conntrack -L -p udp
conntrack -L -p udp - -dport 53
conntrack -L -p tcp - -dport 80
conntrack -L -s 192.168.18.161
dpkg -l nftables
apt list *tables
aptitude search iptables
apt install nftables
cat  /etc/nftables.conf
cat /usr/share/doc/nftables/examples/workstation.nft
nft flush ruleset
nft list ruleset
nft add table inet mi_filtro
nft list ruleset
nft add chain inet mi_filtro denegar {type filter hook input priority 0 \; policy accept;}
nft list ruleset
nft add rule inet mi_filtro denegar ip protocol icmp drop
nft list ruleset
nft add rule inet mi_filtro denegar tcp sport 22 counter drop
nft flush ruleset
nft add table inet filter
nft add table ip nat
nft list tables
nft list ruleset
nft add chain nat prerouting {type nat hook prerouting priority 0 \; }
nft add chain nat postrouting {type nat hook postrouting priority 10 \; }
nft list ruleset
nft add rule ip nat postrouting iof enp0s3 ip saddr 192.168.18.0/24 masquerade
nft add rule ip nat prerouting iif enp0s3 tcp dport 80 dnat to 192.168.18.50
nft list ruleset
nft delete table ip filter
aptitude search clamav
apt install clamav clamav-freshclam clamav-daemon
systemctl stop clamav-freshclam.service
dpkg-reconfigure clamav-freshclam
dpkg-reconfigure clamav-daemon
systemctl status clamav-freshclam.service
clamscan . -r
clamscan . -ri"""
